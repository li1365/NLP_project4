# %%
import pandas as pd
import json
import pickle
from numpy import linalg as LA
import numpy as np

from scipy import spatial
from sklearn.feature_extraction.text import TfidfVectorizer

# with open('training.json', "r") as f:
#     d = json.loads(f.read())

# train = pd.DataFrame.from_dict(d["data"])
# print(train.head(3))

# %% [markdown]
# ## read data

# %%
def read_train(filename):
    train = pd.read_json(filename)
    df = pd.DataFrame()
    context_count = 0
    contexts = []
    qa_dfs = []
    for i in range(len(train)):
        curr = train.loc[i, "data"]
        lsts = curr["paragraphs"] # each contains context, qas
        for item in lsts:
            contexts.append(item["context"])
            curr_qas = item["qas"]
            # columns in tmp_df: [u'answers', u'id', u'is_impossible', u'question', u'context_idx']
            tmp_df = pd.DataFrame.from_records(curr_qas) 
            tmp_df["context_idx"] = context_count
            qa_dfs.append(tmp_df)
            context_count += 1
#         print(i)
    context_df = pd.DataFrame.from_dict({"context": contexts})
    df = pd.concat(qa_dfs)
    return context_df, df

# %%
def save_pickle(filename, obj):
    pickling_on = open(filename + ".pickle","wb")
    pickle.dump(obj, pickling_on)
    pickling_on.close()

# %%
train_context, train = read_train("training.json")
# save_pickle("train_context", train_context)
# save_pickle("train", train)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:23: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
test_context, test = read_train("development.json")
# save_pickle("test_context", test_context)
# save_pickle("test", test)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:23: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
print("length of training is", len(train))
print("length of train context is ", len(train_context))
train.head()
# Out:
# length of training is 69596
# length of train context is  19035
#                                              answers  context_idx  \
# 0  [{'text': 'Dangerously in Love', 'answer_start...            0
# 1  [{'text': 'Houston, Texas', 'answer_start': 166}]            0
# 2  [{'text': 'Mathew Knowles', 'answer_start': 360}]            0
# 3      [{'text': 'late 1990s', 'answer_start': 276}]            0
# 4            [{'text': 'five', 'answer_start': 590}]            0
#
#                          id is_impossible plausible_answers  \
# 0  56d43c5f2ccc5a1400d830ab         False               NaN
# 1  56bf6b0f3aeaaa14008c9601         False               NaN
# 2  56bf6b0f3aeaaa14008c9605         False               NaN
# 3  56bf6b0f3aeaaa14008c9602         False               NaN
# 4  56d43c5f2ccc5a1400d830ad         False               NaN
#
#                                             question
# 0  What was the first album Beyoncé released as a...
# 1      In what city and state did Beyonce  grow up?
# 2             Who managed the Destiny's Child group?
# 3         In which decade did Beyonce become famous?
# 4  How many Grammy awards did Beyoncé win for her...

# %%
print("length of test is", len(test))
print("length of test context is ", len(test_context))
test.head()
# Out:
# length of test is 11856
# length of test context is  1204
#                          id  \
# 0  56ddde6b9a695914005b9628
# 1  56ddde6b9a695914005b9629
# 2  56ddde6b9a695914005b962a
# 3  56ddde6b9a695914005b962b
# 4  56ddde6b9a695914005b962c
#
#                                             question  context_idx
# 0               In what country is Normandy located?            0
# 1                 When were the Normans in Normandy?            0
# 2      From which countries did the Norse originate?            0
# 3                          Who was the Norse leader?            0
# 4  What century did the Normans first gain their ...            0

# %% [markdown]
# - **Load preprocessed dataframes**

# %%
pd.read_pickle("")

# %% [markdown]
# ## baseline system

# %%
def cosine_similarity(arr1, arr2):
    return 1 - spatial.distance.cosine(arr1, arr2.T)
#     return np.dot(arr1.T, arr2)/(LA.norm(arr1)*LA.norm(arr2))

# %%
# add a column with similarity score in df
def compute_sim(context_df, df):
    df["similarity"] = 0
    res = []
    for i in range(len(context_df)):
        vectorizer = TfidfVectorizer(stop_words="english") # build a vectorizer for each context
        curr_context = [context_df.loc[i, "context"]]
        vectorizer.fit(curr_context)
        context_vec = vectorizer.transform(curr_context)
        qas = df[df["context_idx"] == i].reset_index()
        for j in range(len(qas)):
            q_vec = vectorizer.transform([qas.loc[j, "question"]])
            qas.loc[j, "similarity"] = cosine_similarity(q_vec.toarray(), context_vec.toarray())
        res.append(qas)
    res_df = pd.concat(res)
    return res_df

# %%
train_res.describe()
# Out:
#               index   context_idx    similarity
# count  69596.000000  69596.000000  69596.000000
# mean       2.181763   9986.237284      0.325004
# std        2.069136   5281.573580      0.145879
# min        0.000000      0.000000      0.000000
# 25%        0.000000   5853.000000      0.216506
# 50%        2.000000  10085.000000      0.316228
# 75%        3.000000  14463.000000      0.424346
# max       17.000000  19034.000000      0.895669

# %%
train_res = compute_sim(train_context, train)

# %%
train_res["similarity"] = train_res["similarity"].fillna(0)

# %%
from matplotlib import pyplot
true_sim = train_res[train_res["is_impossible"] == True]["similarity"]
false_sim = train_res[train_res["is_impossible"] == False]["similarity"]
bins = np.linspace(0.01, 1, 200)

pyplot.hist(true_sim, bins, alpha=0.5, label='true')
pyplot.hist(false_sim, bins, alpha=0.5, label='false')
pyplot.xlabel('similarity score')
pyplot.ylabel('question count')
pyplot.legend(loc='upper right')
pyplot.show()

# %%
train_res[train_res["is_impossible"] == True]["similarity"].describe()
# Out:
# count    34798.000000
# mean         0.309213
# std          0.145255
# min          0.000000
# 25%          0.199502
# 50%          0.297044
# 75%          0.408248
# max          0.888662
# Name: similarity, dtype: float64

# %%
train_res[train_res["is_impossible"] == False]["similarity"].describe()
# Out:
# count    34798.000000
# mean         0.340795
# std          0.144790
# min          0.000000
# 25%          0.234082
# 50%          0.333333
# 75%          0.439219
# max          0.895669
# Name: similarity, dtype: float64

# %%
test_res
# Out:
#     index                                            answers  context_idx  \
# 0       0            [{'text': '2003', 'answer_start': 526}]            0
# 1       1  [{'text': 'singing and dancing', 'answer_start...            0
# 2       2  [{'text': 'Destiny's Child', 'answer_start': 3...            0
# 0       0           [{'text': 'Jay Z', 'answer_start': 369}]            1
# 1       1      [{'text': 'Dreamgirls', 'answer_start': 260}]            1
# 0       0      [{'text': '60 million', 'answer_start': 445}]            2
# 0       0           [{'text': 'Xerox', 'answer_start': 152}]            3
# 0       0     [{'text': 'Arne Frager', 'answer_start': 303}]            5
# 0       0  [{'text': 'Farrah Franklin and Michelle Willia...            7
# 0       0  [{'text': 'Luckett and Roberson', 'answer_star...            8
# 1       1          [{'text': 'eleven', 'answer_start': 216}]            8
# 2       2        [{'text': 'Survivor', 'answer_start': 593}]            8
# 3       3  [{'text': 'Charlie's Angels.', 'answer_start':...            8
# 0       0     [{'text': 'Work It Out', 'answer_start': 240}]            9
# 1       1  [{'text': 'Fighting Temptations', 'answer_star...            9
# 2       2  [{'text': 'Austin Powers in Goldmember', 'answ...            9
# 3       3  [{'text': 'The Fighting Temptations', 'answer_...            9
# 0       0     [{'text': 'number four', 'answer_start': 123}]           10
# 1       1      [{'text': '11 million', 'answer_start': 419}]           10
# 2       2  [{'text': 'Luther Vandross', 'answer_start': 1...           10
# 0       0  [{'text': 'Destiny Fulfilled.', 'answer_start'...           11
# 0       0         [{'text': '541,000', 'answer_start': 132}]           12
# 1       1           [{'text': 'Jay Z', 'answer_start': 323}]           12
# 2       2           [{'text': 'Jay Z', 'answer_start': 323}]           12
# 0       0      [{'text': '24 million', 'answer_start': 671}]           13
# 0       0   [{'text': 'Taylor Swift', 'answer_start': 1567}]           14
# 0       0  [{'text': 'Sharon Charles', 'answer_start': 724}]           15
# 0       0    [{'text': 'Mariah Carey', 'answer_start': 517}]           16
# 0       0  [{'text': 'The Huffington Post', 'answer_start...           18
# 0       0  [{'text': 'Blue Ivy Carter', 'answer_start': 71}]           20
# ..    ...                                                ...          ...
# 1       1                                                 []        19004
# 0       0                                                 []        19005
# 0       0                                                 []        19007
# 0       0                                                 []        19008
# 0       0                                                 []        19010
# 0       0                                                 []        19011
# 1       1                                                 []        19011
# 0       0                                                 []        19013
# 0       0                                                 []        19015
# 0       0                                                 []        19016
# 1       1                                                 []        19016
# 2       2                                                 []        19016
# 0       0                                                 []        19017
# 0       0                                                 []        19020
# 0       0                                                 []        19022
# 1       1                                                 []        19022
# 0       0                                                 []        19024
# 1       1                                                 []        19024
# 2       2                                                 []        19024
# 0       0                                                 []        19026
# 1       1                                                 []        19026
# 0       0                                                 []        19027
# 1       1                                                 []        19027
# 0       0                                                 []        19028
# 1       1                                                 []        19028
# 0       0                                                 []        19030
# 1       1                                                 []        19030
# 0       0                                                 []        19033
# 1       1                                                 []        19033
# 0       0                                                 []        19034
#
#                           id is_impossible  \
# 0   56d43c5f2ccc5a1400d830ac         False
# 1   56be85543aeaaa14008c9065         False
# 2   56bf6b0f3aeaaa14008c9603         False
# 0   56be86cf3aeaaa14008c9078         False
# 1   56d43da72ccc5a1400d830bf         False
# 0   56d43f7e2ccc5a1400d830c7         False
# 0   56d440df2ccc5a1400d830d1         False
# 0   56be8bab3aeaaa14008c909f         False
# 0   56d462f82ccc5a1400d8311f         False
# 0   56d4831f2ccc5a1400d83157         False
# 1   56be8e353aeaaa14008c90c7         False
# 2   56d4831f2ccc5a1400d83156         False
# 3   56d4831f2ccc5a1400d83154         False
# 0   56d484312ccc5a1400d83160         False
# 1   56d484312ccc5a1400d83162         False
# 2   56bf8c8aa10cfb140055116b         False
# 3   56d484312ccc5a1400d83161         False
# 0   56be90ee3aeaaa14008c90e4         False
# 1   56be90ee3aeaaa14008c90e6         False
# 2   56bf8fc1a10cfb1400551178         False
# 0   56d4baf92ccc5a1400d8317f         False
# 0   56d4bc642ccc5a1400d83191         False
# 1   56bf940da10cfb140055118a         False
# 2   56d4bc642ccc5a1400d83192         False
# 0   56be94703aeaaa14008c9106         False
# 0   56be95823aeaaa14008c910f         False
# 0   56bf99aca10cfb14005511aa         False
# 0   56bf9b57a10cfb14005511b4         False
# 0   56bf9dbda10cfb14005511c8         False
# 0   56d4c4e72ccc5a1400d83219         False
# ..                       ...           ...
# 1   5a6bbc0f4eec6b001a80a566          True
# 0   5a6bbd284eec6b001a80a57c          True
# 0   5a7db5c270df9f001a87506b          True
# 0   5a7db6b770df9f001a875073          True
# 0   5a7db7f770df9f001a875088          True
# 0   5a7db89470df9f001a875094          True
# 1   5a7db89470df9f001a875093          True
# 0   5a7dbca870df9f001a8750b9          True
# 0   5a7dc2b470df9f001a87512c          True
# 0   5a7dc3ae70df9f001a875137          True
# 1   5a7dc3ae70df9f001a875139          True
# 2   5a7dc3ae70df9f001a875136          True
# 0   5a7dc46e70df9f001a87514a          True
# 0   5a7dcb3b70df9f001a87518d          True
# 0   5a7dcd9270df9f001a8751c1          True
# 1   5a7dcd9270df9f001a8751bd          True
# 0   5a7dcf8e70df9f001a875200          True
# 1   5a7dcf8e70df9f001a875201          True
# 2   5a7dcf8e70df9f001a875202          True
# 0   5a7de6bf70df9f001a8752da          True
# 1   5a7de6bf70df9f001a8752d7          True
# 0   5a7de78370df9f001a8752e1          True
# 1   5a7de78370df9f001a8752e4          True
# 0   5a7de83a70df9f001a8752ec          True
# 1   5a7de83a70df9f001a8752ed          True
# 0   5a7de9b570df9f001a875309          True
# 1   5a7de9b570df9f001a875307          True
# 0   5a7e05ef70df9f001a875428          True
# 1   5a7e05ef70df9f001a875426          True
# 0   5a7e070b70df9f001a87543a          True
#
#                                     plausible_answers  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 0                                                 NaN
# 1                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# ..                                                ...
# 1              [{'text': '14%', 'answer_start': 193}]
# 0   [{'text': 'no-fault insurance schemes', 'answe...
# 0        [{'text': 'classical', 'answer_start': 530}]
# 0              [{'text': 'four', 'answer_start': 26}]
# 0             [{'text': 'mass', 'answer_start': 338}]
# 0   [{'text': 'the energy–momentum', 'answer_start...
# 1   [{'text': 'quantifies the amount of matter', '...
# 0             [{'text': 'rest', 'answer_start': 882}]
# 0       [{'text': 'positively', 'answer_start': 169}]
# 0   [{'text': 'Carithers and Grannis', 'answer_sta...
# 1       [{'text': 'elementary', 'answer_start': 665}]
# 2           [{'text': 'baryons', 'answer_start': 67}]
# 0     [{'text': 'gluon fields', 'answer_start': 581}]
# 0   [{'text': 'The Pauli exclusion', 'answer_start...
# 0   [{'text': 'thermodynamics', 'answer_start': 776}]
# 1   [{'text': 'states of aggregation', 'answer_sta...
# 0   [{'text': 'ordinary matter', 'answer_start': 3...
# 1   [{'text': 'a suitable physics laboratory', 'an...
# 2     [{'text': 'antihydrogen', 'answer_start': 414}]
# 0   [{'text': 'elementary fermions (as above) OR g...
# 1   [{'text': 'electromagnetic radiation', 'answer...
# 0   [{'text': 'c. 624 BC–c. 546 BC', 'answer_start...
# 1             [{'text': 'four', 'answer_start': 565}]
# 0        [{'text': 'Aristotle', 'answer_start': 611}]
# 1          [{'text': 'a whole', 'answer_start': 785}]
# 0   [{'text': 'the essential nature of secondary q...
# 1              [{'text': '1643', 'answer_start': 14}]
# 0           [{'text': 'matter', 'answer_start': 711}]
# 1   [{'text': 'The Standard Model', 'answer_start'...
# 0           [{'text': 'Alfvén', 'answer_start': 327}]
#
#                                              question  similarity
# 0       When did Beyoncé release Dangerously in Love?    0.316228
# 1   What areas did Beyonce compete in when she was...         NaN
# 2          In what R&B group was she the lead singer?    0.304290
# 0                     Which artist did Beyonce marry?         NaN
# 1       What was Beyoncé's first acting job, in 2006?    0.345285
# 0   How many records did Beyoncé sell as part of D...    0.169638
# 0   What company did Beyoncé's father work for whe...    0.381246
# 0   Who decided to place Beyonce's group in Star S...    0.356512
# 0   Who replaced Luckett and Roberson in Destiny's...    0.314627
# 0                  Who filed a lawsuit over Survivor?    0.184310
# 1   How many weeks did their single "Independent W...    0.159617
# 2   What was the name of Destiny Child's third album?    0.322543
# 3   Independent Women Part I was on which 2000 fil...    0.249841
# 0   Which song did Beyoncé release as the lead sin...    0.500489
# 1   What song did Beyoncé release as the lead sing...    0.496564
# 2    What film did Beyonce appear in with Mike Myers?    0.286691
# 3   What musical comedy did Beyoncé star in along ...    0.406647
# 0   What was the highest Beyonce's first solo reco...    0.278410
# 1   How many has "Dangerously in Love" sould world...    0.279553
# 2   "The Closer I get to You" was recorded with wh...    0.097823
# 0   What is the name of the final studio album fro...    0.435169
# 0   How many copies did B'Day sell during the firs...    0.233285
# 1   What artist did Beyonce duet with in the singl...    0.214286
# 2   Who collaborated with Beyoncé on the single, D...    0.291606
# 0     How much money did Beyonce's tour make in 2007?    0.117851
# 0   Which singer beat out Beyonce for best video p...    0.342578
# 0   What was the name of the woman she played in O...    0.173097
# 0            Who did they tie with for six top songs?    0.094072
# 0                Who did she tell about the donation?         NaN
# 0                 What did Beyoncé name her daughter?    0.229416
# ..                                                ...         ...
# 1   What percentage of deaths does unipolar depres...    0.466252
# 0                        What typically covers an MI?    0.114708
# 0   All particles with rest mass have what kind of...    0.656392
# 0                 How many forms of solids are there?         NaN
# 0              What is poorly defined besides matter?    0.476290
# 0        What does gravity contribute to in a system?    0.099504
# 1         What can the energy-momentum tensor not do?    0.344691
# 0   Kinetic energy cannot add what kind of mass to...    0.553912
# 0                  What type of charge do atoms have?    0.336861
# 0         Who determined that electrons were leptons?    0.225733
# 1     What type of fermions are protons and neutrons?    0.230388
# 2                          What are quarks made from?    0.319235
# 0                        What binds an atom together?    0.071982
# 0   What is the name of the principle for the grou...    0.304604
# 0                   What field studies nanomaterials?    0.178017
# 1                           What are phases known as?    0.237356
# 0                    What does antimatter annihilate?    0.424264
# 1                   Where is ordinary matter created?    0.200000
# 2              What is an example of an antiparticle?         NaN
# 0                         What does dark matter form?    0.473879
# 1      What does dark matter emit to make it visible?    0.458831
# 0                            When did Socratics live?    0.078811
# 1              How many elements did Democritus name?    0.111456
# 0     Who said matter had actuality in and of itself?    0.446304
# 1   Aristotle said parts have existence outside of...    0.208232
# 0      What did Newton reject that Descartes did not?    0.379049
# 1                            When was Descartes born?    0.214423
# 0     Mass and energy can always be compared to what?    0.282843
# 1         What model satisfactorily explains gravity?    0.188562
# 0                Who coined the term partonic matter?    0.628539
#
# [17400 rows x 8 columns]

# %%
test_res = compute_sim(test_context, test)
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/spatial/distance.py:698: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)

# %%
def predict_baseline(x, thred):
    if x < thred:
        return 1
    else:
        return 0

# %%
threshold = 0.25
test_res["predicted"] = [predict_baseline(x, threshold) for x in test_res["similarity"]]

# %%
output = test_res[["id", "predicted"]].to_json(orient='values')[1:-1].replace("[", "")
output = "{" +  output.replace("]", "") + "}"
output = output.replace('",', '": ')

# %%
with open('dev_baseline.json', 'w') as f:
    f.write(output)
